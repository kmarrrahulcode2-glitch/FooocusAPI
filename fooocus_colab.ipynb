# %%
# !pip install pyngrok

# %%
# !pip install pygit2==1.15.1

# %cd /content
# !git clone https://github.com/mrhan1993/FooocusAPI
# %cd /content/FooocusAPI

# %%
# !wget --load-cookies /content/civitai.com_cookies.txt -O /content/FooocusAPI/models/checkpoints/cyberrealisticPony_v160.safetensors "https://civitai.com/api/download/models/2255476?type=Model&format=SafeTensor&size=pruned&fp=fp16"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from google.colab import userdata
print(userdata.get('NGROK_AUTHTOKEN'))
os.environ["NGROK_AUTHTOKEN"] = userdata.get('NGROK_AUTHTOKEN')

# Print all environment variables
for key, value in os.environ.items():
    print(f"{key}: {value}")

# %%
#!python entry_with_update.py --always-high-vram
# !python launch.py --listen 0.0.0.0 --port 7865
#!python launch.py --listen 0.0.0.0 --port 7865 --nowebui
